# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import math
import random

import pydot
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

from IPython.display import Image

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.externals.six import StringIO  
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.metrics import mean_squared_error,confusion_matrix, classification_report

from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from statsmodels.stats.anova import anova_lm
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, roc_curve, auc, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV

# %matplotlib inline
plt.style.use('seaborn-white')
# Out:
# C:\Users\jkom8\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
# This function creates images of tree models using pydot
def print_tree(estimator, features, class_names=None, filled=True):
    tree = estimator
    names = features
    color = filled
    classn = class_names
    
    dot_data = StringIO()
    export_graphviz(estimator, out_file=dot_data, feature_names=features, class_names=classn, filled=filled)
    graph = pydot.graph_from_dot_data(dot_data.getvalue())
    return(graph)

def show_grid_search(model, X_train, y_train, tuned_parameters, scores):
    for score in scores:
        print("# Tuning hyper-parameters for %s" % score)
        print()

        clf = GridSearchCV(
            model, tuned_parameters, cv=3,
            verbose=10, scoring='%s_macro' % score, n_jobs=-1
        )
        clf.fit(X_train, y_train)

        print("Best parameters set found on development set:")
        print()
        print(clf.best_params_)
        print()
        print("Grid scores on development set:")
        print()
        means = clf.cv_results_['mean_test_score']
        stds = clf.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, clf.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"
                  % (mean, std * 2, params))
        print()

        print("Detailed classification report:")
        print()
        print("The model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        print()
        y_true, y_pred = y_test, clf.predict(X_test)
        print(classification_report(y_true, y_pred))
        print()

# function for printing the ROC curve
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

# %%
# Load data
df = pd.read_csv("nhl_game_data/game_teams_stats.csv")
# normalize 
df['shots'] = (df['shots'] - df['shots'].mean()) / (df['shots'].max() - df['shots'].min())
df['goals'] = (df['goals'] - df['goals'].mean()) / (df['goals'].max() - df['goals'].min())
df['pim'] = (df['pim'] - df['pim'].mean()) / (df['pim'].max() - df['pim'].min())
df['powerPlayGoals'] = (df['powerPlayGoals'] - df['powerPlayGoals'].mean()) / (df['powerPlayGoals'].max() - df['powerPlayGoals'].min())
df['giveaways'] = (df['giveaways'] - df['giveaways'].mean()) / (df['giveaways'].max() - df['giveaways'].min())
df['takeaways'] = (df['takeaways'] - df['takeaways'].mean()) / (df['takeaways'].max() - df['takeaways'].min())
df['faceOffWinPercentage'] = (df['faceOffWinPercentage'] - df['faceOffWinPercentage'].mean()) / (df['faceOffWinPercentage'].max() - df['faceOffWinPercentage'].min())

# Change catergorical data to numerical
df['won_true'] = df['won'].astype(int)
# Features
X = df[['goals', 'shots', 'pim', 'powerPlayGoals', 'giveaways', 'takeaways', 'faceOffWinPercentage']]
# Target Variable
y = df['won_true']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
svc = SVC()
dtc = DecisionTreeClassifier()
rfc = RandomForestClassifier()
bc = BaggingClassifier()

# %% [markdown]
# We will start with an SVC model parameter tuning.

# %%
# Select the optimal C, kernel and gamma parameter by cross-validation
tuned_parameters = [{'kernel':['rbf'], 'C':(0.0001, 0.001, 0.01, .1, 1, 10),
                    'gamma':(0.01, 0.1, 1, 10)}]
#clf = GridSearchCV(svc, tuned_parameters, n_jobs=-1, cv=3, scoring='accuracy', verbose=10)
scores = ['precision', 'recall']
show_grid_search(svc, X_train, y_train, tuned_parameters, scores)
# Out:
# # Tuning hyper-parameters for precision
#
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   22.5s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   27.5s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=-1)]: Done  57 out of  72 | elapsed:   32.7s remaining:    8.5s
# [Parallel(n_jobs=-1)]: Done  65 out of  72 | elapsed:   36.3s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done  72 out of  72 | elapsed:   39.4s finished
# Best parameters set found on development set:
#
# {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.251 (+/-0.000) for {'C': 0.0001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.251 (+/-0.000) for {'C': 0.0001, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.251 (+/-0.000) for {'C': 0.0001, 'gamma': 1, 'kernel': 'rbf'}
# 0.251 (+/-0.000) for {'C': 0.0001, 'gamma': 10, 'kernel': 'rbf'}
# 0.251 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.251 (+/-0.000) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.753 (+/-0.005) for {'C': 0.001, 'gamma': 1, 'kernel': 'rbf'}
# 0.763 (+/-0.006) for {'C': 0.001, 'gamma': 10, 'kernel': 'rbf'}
# 0.251 (+/-0.000) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.757 (+/-0.002) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.775 (+/-0.001) for {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
# 0.775 (+/-0.003) for {'C': 0.01, 'gamma': 10, 'kernel': 'rbf'}
# 0.758 (+/-0.004) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.775 (+/-0.001) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.778 (+/-0.004) for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 0.777 (+/-0.001) for {'C': 0.1, 'gamma': 10, 'kernel': 'rbf'}
# 0.775 (+/-0.001) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.777 (+/-0.004) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.778 (+/-0.002) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 0.775 (+/-0.001) for {'C': 1, 'gamma': 10, 'kernel': 'rbf'}
# 0.777 (+/-0.003) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.778 (+/-0.004) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.777 (+/-0.002) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.773 (+/-0.003) for {'C': 10, 'gamma': 10, 'kernel': 'rbf'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78      3413
#            1       0.78      0.77      0.78      3448
#
#     accuracy                           0.78      6861
#    macro avg       0.78      0.78      0.78      6861
# weighted avg       0.78      0.78      0.78      6861
#
#
# # Tuning hyper-parameters for recall
#
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   20.2s
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:   25.2s
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done  57 out of  72 | elapsed:   30.3s remaining:    7.9s
# [Parallel(n_jobs=-1)]: Done  65 out of  72 | elapsed:   34.1s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done  72 out of  72 | elapsed:   37.6s finished
# Best parameters set found on development set:
#
# {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.500 (+/-0.000) for {'C': 0.0001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 0.0001, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 0.0001, 'gamma': 1, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 0.0001, 'gamma': 10, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.549 (+/-0.002) for {'C': 0.001, 'gamma': 1, 'kernel': 'rbf'}
# 0.763 (+/-0.006) for {'C': 0.001, 'gamma': 10, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.654 (+/-0.001) for {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.775 (+/-0.001) for {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
# 0.775 (+/-0.003) for {'C': 0.01, 'gamma': 10, 'kernel': 'rbf'}
# 0.660 (+/-0.004) for {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.774 (+/-0.001) for {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.778 (+/-0.004) for {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}
# 0.777 (+/-0.001) for {'C': 0.1, 'gamma': 10, 'kernel': 'rbf'}
# 0.774 (+/-0.001) for {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.777 (+/-0.004) for {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.777 (+/-0.002) for {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 0.775 (+/-0.001) for {'C': 1, 'gamma': 10, 'kernel': 'rbf'}
# 0.777 (+/-0.003) for {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.778 (+/-0.004) for {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.777 (+/-0.002) for {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.773 (+/-0.002) for {'C': 10, 'gamma': 10, 'kernel': 'rbf'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78      3413
#            1       0.78      0.77      0.78      3448
#
#     accuracy                           0.78      6861
#    macro avg       0.78      0.78      0.78      6861
# weighted avg       0.78      0.78      0.78      6861

# %% [markdown]
# The best parameters have been shown above for an SVC model.

# %%
svc2 = SVC(kernel='rbf', C=0.1, gamma=1, probability=True)
svc2.fit(X_train, y_train)
# Out:
# SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=True, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
pred = svc2.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.7778749453432444

# %% [markdown]
# ROC for SCV:

# %%
y_probs = svc2.predict_proba(X_test) # we have to get the probability values to plot roc curve
y_probs = y_probs[:, 1] # keep probabilities for the positive outcome only
fpr, tpr, _ = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)
plot_roc_curve(fpr, tpr)
svc_auc = roc_auc_score(y_test, y_probs)
svc_auc
# Out:
# 0.8598652586024637

# %% [markdown]
# Lets move onto a Decision Tree Classifier model.

# %%
tuned_parameters = [{'criterion':('gini', 'entropy'),
                    'splitter':('best', 'random'),
                    'max_features':('auto', 'sqrt', 'log2'),
                    'max_leaf_nodes':(10, 25, 50, 100, 150),
                    'class_weight':['balanced']},
                   {'criterion':('gini', 'entropy'),
                    'splitter':('best', 'random')}]

show_grid_search(dtc, X_train, y_train, tuned_parameters, scores)
# Out:
# # Tuning hyper-parameters for precision
#
# Fitting 3 folds for each of 64 candidates, totalling 192 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0660s.) Setting batch_size=6.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 192 out of 192 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0250s.) Setting batch_size=14.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.0s
# Best parameters set found on development set:
#
# {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 25, 'splitter': 'best'}
#
# Grid scores on development set:
#
# 0.747 (+/-0.075) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.671 (+/-0.162) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.741 (+/-0.045) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.681 (+/-0.134) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.750 (+/-0.064) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.676 (+/-0.047) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.754 (+/-0.021) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.704 (+/-0.126) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.755 (+/-0.019) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.712 (+/-0.111) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.708 (+/-0.120) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.672 (+/-0.095) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.772 (+/-0.003) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.649 (+/-0.016) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.744 (+/-0.076) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.692 (+/-0.109) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.767 (+/-0.003) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.674 (+/-0.090) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.742 (+/-0.008) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.730 (+/-0.077) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.743 (+/-0.070) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.664 (+/-0.152) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.746 (+/-0.022) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.733 (+/-0.086) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.721 (+/-0.076) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.666 (+/-0.157) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.758 (+/-0.005) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.686 (+/-0.106) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.754 (+/-0.028) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.712 (+/-0.128) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.736 (+/-0.060) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.695 (+/-0.146) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.740 (+/-0.047) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.620 (+/-0.087) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.749 (+/-0.054) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.712 (+/-0.058) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.749 (+/-0.045) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.658 (+/-0.141) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.748 (+/-0.027) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.708 (+/-0.095) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.748 (+/-0.051) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.566 (+/-0.033) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.745 (+/-0.038) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.718 (+/-0.158) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.767 (+/-0.014) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.717 (+/-0.129) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.760 (+/-0.023) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.767 (+/-0.009) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.742 (+/-0.073) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.720 (+/-0.065) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.679 (+/-0.201) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.703 (+/-0.150) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.728 (+/-0.029) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.718 (+/-0.068) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.726 (+/-0.069) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.714 (+/-0.106) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.765 (+/-0.003) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.690 (+/-0.062) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.757 (+/-0.038) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.755 (+/-0.022) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.682 (+/-0.013) for {'criterion': 'gini', 'splitter': 'best'}
# 0.680 (+/-0.007) for {'criterion': 'gini', 'splitter': 'random'}
# 0.684 (+/-0.011) for {'criterion': 'entropy', 'splitter': 'best'}
# 0.684 (+/-0.003) for {'criterion': 'entropy', 'splitter': 'random'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78      3413
#            1       0.79      0.75      0.77      3448
#
#     accuracy                           0.78      6861
#    macro avg       0.78      0.78      0.78      6861
# weighted avg       0.78      0.78      0.78      6861
#
#
# # Tuning hyper-parameters for recall
#
# Fitting 3 folds for each of 64 candidates, totalling 192 fits
# Best parameters set found on development set:
#
# {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 150, 'splitter': 'best'}
#
# Grid scores on development set:
#
# 0.753 (+/-0.033) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.567 (+/-0.076) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.748 (+/-0.038) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.702 (+/-0.103) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.753 (+/-0.040) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.622 (+/-0.210) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.757 (+/-0.028) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.729 (+/-0.102) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.758 (+/-0.015) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.742 (+/-0.044) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'auto', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.695 (+/-0.116) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.674 (+/-0.080) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.695 (+/-0.031) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.669 (+/-0.191) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.759 (+/-0.019) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.723 (+/-0.046) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.760 (+/-0.023) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.721 (+/-0.090) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.751 (+/-0.025) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.696 (+/-0.085) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.598 (+/-0.105) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.671 (+/-0.106) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.725 (+/-0.069) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.585 (+/-0.041) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.734 (+/-0.085) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.679 (+/-0.110) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.743 (+/-0.037) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.684 (+/-0.129) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.745 (+/-0.042) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.704 (+/-0.131) for {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'log2', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.723 (+/-0.145) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.701 (+/-0.140) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.719 (+/-0.080) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.724 (+/-0.136) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.714 (+/-0.079) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.701 (+/-0.187) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.749 (+/-0.033) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.719 (+/-0.101) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.744 (+/-0.038) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.689 (+/-0.134) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.697 (+/-0.107) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.676 (+/-0.114) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.757 (+/-0.040) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.587 (+/-0.119) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.759 (+/-0.031) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.636 (+/-0.143) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.752 (+/-0.038) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.669 (+/-0.054) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.765 (+/-0.002) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.740 (+/-0.048) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'sqrt', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.690 (+/-0.116) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 10, 'splitter': 'best'}
# 0.643 (+/-0.132) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 10, 'splitter': 'random'}
# 0.725 (+/-0.123) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 25, 'splitter': 'best'}
# 0.587 (+/-0.137) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 25, 'splitter': 'random'}
# 0.712 (+/-0.090) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 50, 'splitter': 'best'}
# 0.652 (+/-0.170) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 50, 'splitter': 'random'}
# 0.733 (+/-0.039) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 100, 'splitter': 'best'}
# 0.723 (+/-0.029) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 100, 'splitter': 'random'}
# 0.733 (+/-0.028) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 150, 'splitter': 'best'}
# 0.740 (+/-0.043) for {'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'log2', 'max_leaf_nodes': 150, 'splitter': 'random'}
# 0.681 (+/-0.012) for {'criterion': 'gini', 'splitter': 'best'}
# 0.681 (+/-0.014) for {'criterion': 'gini', 'splitter': 'random'}
# 0.683 (+/-0.015) for {'criterion': 'entropy', 'splitter': 'best'}
# 0.684 (+/-0.009) for {'criterion': 'entropy', 'splitter': 'random'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77      3413
#            1       0.77      0.78      0.77      3448
#
#     accuracy                           0.77      6861
#    macro avg       0.77      0.77      0.77      6861
# weighted avg       0.77      0.77      0.77      6861
# [Parallel(n_jobs=-1)]: Done 192 out of 192 | elapsed:    0.6s finished

# %% [markdown]
# The best parameters have been shown above for a Decision Tree Classifier model.

# %%
#{'class_weight': 'balanced', 'criterion': 'entropy', 'max_features': 'auto', 'max_leaf_nodes': 50, 'splitter': 'best'}
dtc2 = DecisionTreeClassifier(class_weight='balanced', criterion='entropy', max_features='auto', max_leaf_nodes=50, splitter='best')
dtc2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=50,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
#Predict the response for test dataset
pred = dtc2.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.7759801778166449

# %%
graph, = print_tree(dtc2, features=['goals', 'shots', 'pim', 'powerPlayGoals', 'giveaways', 'takeaways', 'faceOffWinPercentage'])
Image(graph.create_png())

# %% [markdown]
# ROC for DTC:

# %%
y_probs = dtc2.predict_proba(X_test) # we have to get the probability values to plot roc curve
y_probs = y_probs[:, 1] # keep probabilities for the positive outcome only
fpr, tpr, _ = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)
plot_roc_curve(fpr, tpr)
dtc_auc = roc_auc_score(y_test, y_probs)
dtc_auc
# Out:
# 0.8370188996895316

# %% [markdown]
# Next, we will look at a Random Forest Classifier.

# %%
tuned_parameters = [{'n_estimators':(10, 50, 100, 200, 500),
                    'criterion':('gini', 'entropy')}]

show_grid_search(rfc, X_train, y_train, tuned_parameters, scores)
# Out:
# # Tuning hyper-parameters for precision
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  11 out of  30 | elapsed:    1.4s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done  15 out of  30 | elapsed:    1.9s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done  19 out of  30 | elapsed:    3.0s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  23 out of  30 | elapsed:    4.8s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  27 out of  30 | elapsed:    6.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    9.2s finished
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'n_estimators': 500}
#
# Grid scores on development set:
#
# 0.750 (+/-0.010) for {'criterion': 'gini', 'n_estimators': 10}
# 0.760 (+/-0.003) for {'criterion': 'gini', 'n_estimators': 50}
# 0.763 (+/-0.008) for {'criterion': 'gini', 'n_estimators': 100}
# 0.764 (+/-0.009) for {'criterion': 'gini', 'n_estimators': 200}
# 0.764 (+/-0.008) for {'criterion': 'gini', 'n_estimators': 500}
# 0.744 (+/-0.013) for {'criterion': 'entropy', 'n_estimators': 10}
# 0.759 (+/-0.008) for {'criterion': 'entropy', 'n_estimators': 50}
# 0.762 (+/-0.008) for {'criterion': 'entropy', 'n_estimators': 100}
# 0.762 (+/-0.007) for {'criterion': 'entropy', 'n_estimators': 200}
# 0.763 (+/-0.005) for {'criterion': 'entropy', 'n_estimators': 500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76      3413
#            1       0.77      0.76      0.77      3448
#
#     accuracy                           0.76      6861
#    macro avg       0.76      0.76      0.76      6861
# weighted avg       0.76      0.76      0.76      6861
#
#
# # Tuning hyper-parameters for recall
#
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1470s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done   7 out of  30 | elapsed:    0.8s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done  11 out of  30 | elapsed:    1.3s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done  15 out of  30 | elapsed:    1.7s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  19 out of  30 | elapsed:    2.9s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done  23 out of  30 | elapsed:    5.8s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   13.6s finished
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'n_estimators': 500}
#
# Grid scores on development set:
#
# 0.750 (+/-0.007) for {'criterion': 'gini', 'n_estimators': 10}
# 0.762 (+/-0.005) for {'criterion': 'gini', 'n_estimators': 50}
# 0.763 (+/-0.007) for {'criterion': 'gini', 'n_estimators': 100}
# 0.763 (+/-0.009) for {'criterion': 'gini', 'n_estimators': 200}
# 0.764 (+/-0.003) for {'criterion': 'gini', 'n_estimators': 500}
# 0.743 (+/-0.015) for {'criterion': 'entropy', 'n_estimators': 10}
# 0.759 (+/-0.005) for {'criterion': 'entropy', 'n_estimators': 50}
# 0.762 (+/-0.008) for {'criterion': 'entropy', 'n_estimators': 100}
# 0.762 (+/-0.006) for {'criterion': 'entropy', 'n_estimators': 200}
# 0.763 (+/-0.006) for {'criterion': 'entropy', 'n_estimators': 500}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76      3413
#            1       0.77      0.76      0.76      3448
#
#     accuracy                           0.76      6861
#    macro avg       0.76      0.76      0.76      6861
# weighted avg       0.76      0.76      0.76      6861

# %%
rfc2 = RandomForestClassifier(n_estimators=500, criterion='gini')
rfc2.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
pred = rfc2.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.7638828159160472

# %% [markdown]
# ROC for RFC:

# %%
y_probs = rfc2.predict_proba(X_test) # we have to get the probability values to plot roc curve
y_probs = y_probs[:, 1] # keep probabilities for the positive outcome only
fpr, tpr, _ = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)
plot_roc_curve(fpr, tpr)
rfc_auc = roc_auc_score(y_test, y_probs)
rfc_auc
# Out:
# 0.8476820322596216

# %% [markdown]
# Last, lets look at the Bagging Classifier model.

# %%
tuned_parameters = [{'n_estimators':(1, 5, 10, 20, 50),
                    'bootstrap':[True],
                    'bootstrap_features':(True, False),
                    'oob_score':[True],
                    'warm_start':[False]},
                   {'n_estimators':(1, 5, 10, 20, 50),
                    'bootstrap':(True, False),
                    'bootstrap_features':(True, False),
                    'oob_score':[False],
                    'warm_start':[True]}]

show_grid_search(bc, X_train, y_train, tuned_parameters, scores)
# Out:
# # Tuning hyper-parameters for precision
#
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0390s.) Setting batch_size=10.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done  17 out of  90 | elapsed:    0.6s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:    7.9s finished
# Best parameters set found on development set:
#
# {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
#
# Grid scores on development set:
#
# 0.628 (+/-0.183) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 1, 'oob_score': True, 'warm_start': False}
# 0.691 (+/-0.048) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 5, 'oob_score': True, 'warm_start': False}
# 0.727 (+/-0.023) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 10, 'oob_score': True, 'warm_start': False}
# 0.732 (+/-0.010) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 20, 'oob_score': True, 'warm_start': False}
# 0.748 (+/-0.006) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.685 (+/-0.002) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 1, 'oob_score': True, 'warm_start': False}
# 0.726 (+/-0.013) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 5, 'oob_score': True, 'warm_start': False}
# 0.735 (+/-0.009) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 10, 'oob_score': True, 'warm_start': False}
# 0.750 (+/-0.013) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 20, 'oob_score': True, 'warm_start': False}
# 0.750 (+/-0.010) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.526 (+/-0.012) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 1, 'oob_score': False, 'warm_start': True}
# 0.701 (+/-0.055) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 5, 'oob_score': False, 'warm_start': True}
# 0.727 (+/-0.007) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 10, 'oob_score': False, 'warm_start': True}
# 0.746 (+/-0.011) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 20, 'oob_score': False, 'warm_start': True}
# 0.754 (+/-0.013) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.685 (+/-0.008) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 1, 'oob_score': False, 'warm_start': True}
# 0.717 (+/-0.005) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 5, 'oob_score': False, 'warm_start': True}
# 0.734 (+/-0.021) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 10, 'oob_score': False, 'warm_start': True}
# 0.747 (+/-0.013) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 20, 'oob_score': False, 'warm_start': True}
# 0.749 (+/-0.007) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.634 (+/-0.148) for {'bootstrap': False, 'bootstrap_features': True, 'n_estimators': 1, 'oob_score': False, 'warm_start': True}
# 0.707 (+/-0.024) for {'bootstrap': False, 'bootstrap_features': True, 'n_estimators': 5, 'oob_score': False, 'warm_start': True}
# 0.706 (+/-0.039) for {'bootstrap': False, 'bootstrap_features': True, 'n_estimators': 10, 'oob_score': False, 'warm_start': True}
# 0.720 (+/-0.031) for {'bootstrap': False, 'bootstrap_features': True, 'n_estimators': 20, 'oob_score': False, 'warm_start': True}
# 0.731 (+/-0.013) for {'bootstrap': False, 'bootstrap_features': True, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.682 (+/-0.016) for {'bootstrap': False, 'bootstrap_features': False, 'n_estimators': 1, 'oob_score': False, 'warm_start': True}
# 0.682 (+/-0.017) for {'bootstrap': False, 'bootstrap_features': False, 'n_estimators': 5, 'oob_score': False, 'warm_start': True}
# 0.686 (+/-0.010) for {'bootstrap': False, 'bootstrap_features': False, 'n_estimators': 10, 'oob_score': False, 'warm_start': True}
# 0.685 (+/-0.014) for {'bootstrap': False, 'bootstrap_features': False, 'n_estimators': 20, 'oob_score': False, 'warm_start': True}
# 0.685 (+/-0.009) for {'bootstrap': False, 'bootstrap_features': False, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76      3413
#            1       0.76      0.76      0.76      3448
#
#     accuracy                           0.76      6861
#    macro avg       0.76      0.76      0.76      6861
# weighted avg       0.76      0.76      0.76      6861
#
#
# # Tuning hyper-parameters for recall
#
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0380s.) Setting batch_size=10.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done  17 out of  90 | elapsed:    0.6s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:    7.9s finished
# Best parameters set found on development set:
#
# {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
#
# Grid scores on development set:
#
# 0.699 (+/-0.018) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 1, 'oob_score': True, 'warm_start': False}
# 0.716 (+/-0.026) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 5, 'oob_score': True, 'warm_start': False}
# 0.711 (+/-0.006) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 10, 'oob_score': True, 'warm_start': False}
# 0.730 (+/-0.028) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 20, 'oob_score': True, 'warm_start': False}
# 0.742 (+/-0.012) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.683 (+/-0.010) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 1, 'oob_score': True, 'warm_start': False}
# 0.728 (+/-0.007) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 5, 'oob_score': True, 'warm_start': False}
# 0.734 (+/-0.012) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 10, 'oob_score': True, 'warm_start': False}
# 0.743 (+/-0.012) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 20, 'oob_score': True, 'warm_start': False}
# 0.755 (+/-0.011) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.536 (+/-0.039) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 1, 'oob_score': False, 'warm_start': True}
# 0.664 (+/-0.120) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 5, 'oob_score': False, 'warm_start': True}
# 0.717 (+/-0.021) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 10, 'oob_score': False, 'warm_start': True}
# 0.737 (+/-0.005) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 20, 'oob_score': False, 'warm_start': True}
# 0.750 (+/-0.013) for {'bootstrap': True, 'bootstrap_features': True, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.683 (+/-0.010) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 1, 'oob_score': False, 'warm_start': True}
# 0.723 (+/-0.011) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 5, 'oob_score': False, 'warm_start': True}
# 0.733 (+/-0.014) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 10, 'oob_score': False, 'warm_start': True}
# 0.742 (+/-0.005) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 20, 'oob_score': False, 'warm_start': True}
# 0.751 (+/-0.005) for {'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.626 (+/-0.144) for {'bootstrap': False, 'bootstrap_features': True, 'n_estimators': 1, 'oob_score': False, 'warm_start': True}
# 0.705 (+/-0.008) for {'bootstrap': False, 'bootstrap_features': True, 'n_estimators': 5, 'oob_score': False, 'warm_start': True}
# 0.699 (+/-0.025) for {'bootstrap': False, 'bootstrap_features': True, 'n_estimators': 10, 'oob_score': False, 'warm_start': True}
# 0.711 (+/-0.015) for {'bootstrap': False, 'bootstrap_features': True, 'n_estimators': 20, 'oob_score': False, 'warm_start': True}
# 0.730 (+/-0.010) for {'bootstrap': False, 'bootstrap_features': True, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.684 (+/-0.016) for {'bootstrap': False, 'bootstrap_features': False, 'n_estimators': 1, 'oob_score': False, 'warm_start': True}
# 0.683 (+/-0.011) for {'bootstrap': False, 'bootstrap_features': False, 'n_estimators': 5, 'oob_score': False, 'warm_start': True}
# 0.685 (+/-0.012) for {'bootstrap': False, 'bootstrap_features': False, 'n_estimators': 10, 'oob_score': False, 'warm_start': True}
# 0.684 (+/-0.011) for {'bootstrap': False, 'bootstrap_features': False, 'n_estimators': 20, 'oob_score': False, 'warm_start': True}
# 0.685 (+/-0.011) for {'bootstrap': False, 'bootstrap_features': False, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.76      0.76      3413
#            1       0.76      0.75      0.76      3448
#
#     accuracy                           0.76      6861
#    macro avg       0.76      0.76      0.76      6861
# weighted avg       0.76      0.76      0.76      6861

# %%
#{'bootstrap': True, 'bootstrap_features': False, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
bc2 = BaggingClassifier(n_estimators=50,bootstrap=True,bootstrap_features=False,oob_score=True,warm_start=False)
bc2.fit(X_train, y_train)
# Out:
# BaggingClassifier(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                   max_features=1.0, max_samples=1.0, n_estimators=50,
#                   n_jobs=None, oob_score=True, random_state=None, verbose=0,
#                   warm_start=False)

# %%
pred = bc2.predict(X_test)
print("Accuracy:", metrics.accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.7567409998542487

# %% [markdown]
# ROC for BC:

# %%
y_probs = bc2.predict_proba(X_test) # we have to get the probability values to plot roc curve
y_probs = y_probs[:, 1] # keep probabilities for the positive outcome only
fpr, tpr, _ = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)
plot_roc_curve(fpr, tpr)
bc_auc = roc_auc_score(y_test, y_probs)
bc_auc
# Out:
# 0.8375548010439137
