# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
import math
import random
import statsmodels.formula.api as smf

# %%
df_sales = pd.read_csv("data/advertising.csv")
df_sales.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
results = smf.ols('Sales ~ TV', data = df_sales).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Thu, 23 Jan 2020   Prob (F-statistic):           1.47e-42
# Time:                        14:35:25   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
three_results = smf.ols('Sales ~ TV + Radio + Newspaper', data = df_sales).fit()

# %%
three_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Thu, 23 Jan 2020   Prob (F-statistic):           1.58e-96
# Time:                        14:35:40   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
df_sales.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
three_results.rsquared
# Out:
# 0.8972106381789522

# %%
gender_df = pd.read_csv("data/Credit.csv")

# %%
gender_df.describe()
# Out:
#            Income         Limit      Rating       Cards         Age  \
# count  400.000000    400.000000  400.000000  400.000000  400.000000
# mean    45.218885   4735.600000  354.940000    2.957500   55.667500
# std     35.244273   2308.198848  154.724143    1.371275   17.249807
# min     10.354000    855.000000   93.000000    1.000000   23.000000
# 25%     21.007250   3088.000000  247.250000    2.000000   41.750000
# 50%     33.115500   4622.500000  344.000000    3.000000   56.000000
# 75%     57.470750   5872.750000  437.250000    4.000000   70.000000
# max    186.634000  13913.000000  982.000000    9.000000   98.000000
#
#         Education      Balance
# count  400.000000   400.000000
# mean    13.450000   520.015000
# std      3.125207   459.758877
# min      5.000000     0.000000
# 25%     11.000000    68.750000
# 50%     14.000000   459.500000
# 75%     16.000000   863.000000
# max     20.000000  1999.000000

# %%
gender_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
# Income       400 non-null float64
# Limit        400 non-null int64
# Rating       400 non-null int64
# Cards        400 non-null int64
# Age          400 non-null int64
# Education    400 non-null int64
# Gender       400 non-null object
# Student      400 non-null object
# Married      400 non-null object
# Ethnicity    400 non-null object
# Balance      400 non-null int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 34.5+ KB

# %%
gender_df['Female'] = (gender_df.Gender == 'Female').astype(int)

# %%
gender_df.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   14.891   3606     283      2   34         11    Male      No     Yes
# 1  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2  104.593   7075     514      4   71         11    Male      No      No
# 3  148.924   9504     681      3   36         11  Female      No      No
# 4   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance  Female
# 0  Caucasian      333       0
# 1      Asian      903       1
# 2      Asian      580       0
# 3      Asian      964       1
# 4  Caucasian      331       0

# %%
gender_df['Yes_Married'] = (gender_df.Married == 'Yes').astype(int)

# %%
gender_df.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   14.891   3606     283      2   34         11    Male      No     Yes
# 1  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2  104.593   7075     514      4   71         11    Male      No      No
# 3  148.924   9504     681      3   36         11  Female      No      No
# 4   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance  Female  Yes_Married
# 0  Caucasian      333       0            1
# 1      Asian      903       1            1
# 2      Asian      580       0            0
# 3      Asian      964       1            0
# 4  Caucasian      331       0            1

# %%
results = smf.ols('Balance ~ Female', data = gender_df).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Balance   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.1836
# Date:                Thu, 23 Jan 2020   Prob (F-statistic):              0.669
# Time:                        15:06:19   Log-Likelihood:                -3019.3
# No. Observations:                 400   AIC:                             6043.
# Df Residuals:                     398   BIC:                             6051.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    509.8031     33.128     15.389      0.000     444.675     574.931
# ...

# %%
gender_df.corr()
# Out:
#                Income     Limit    Rating     Cards       Age  Education  \
# Income       1.000000  0.792088  0.791378 -0.018273  0.175338  -0.027692
# Limit        0.792088  1.000000  0.996880  0.010231  0.100888  -0.023549
# Rating       0.791378  0.996880  1.000000  0.053239  0.103165  -0.030136
# Cards       -0.018273  0.010231  0.053239  1.000000  0.042948  -0.051084
# Age          0.175338  0.100888  0.103165  0.042948  1.000000   0.003619
# Education   -0.027692 -0.023549 -0.030136 -0.051084  0.003619   1.000000
# Balance      0.463656  0.861697  0.863625  0.086456  0.001835  -0.008062
# Female      -0.010738  0.009397  0.008885 -0.022658  0.004015  -0.005049
# Yes_Married  0.035652  0.031155  0.036751 -0.009695 -0.073136   0.048911
#
#               Balance    Female  Yes_Married
# Income       0.463656 -0.010738     0.035652
# Limit        0.861697  0.009397     0.031155
# Rating       0.863625  0.008885     0.036751
# Cards        0.086456 -0.022658    -0.009695
# ...

# %%
# Out:
#   File "<ipython-input-48-d2b4896d4cfc>", line 1
#     if (gender_df['Female'] == 1) {
#                                   ^
# SyntaxError: invalid syntax
